# %%
from h2_gym.data.shipping import NGDemand

# %%
data = NGDemand('jodi-gas_wdb_16147546018076.csv')

# %%
data._data.rename(columns={data._data.columns[0]: "Country"}, inplace=True)

# %%
data._data
# Out:
#           Country                       Country     Jan2009     Feb2009  \
# 0             NaN                          Unit  Terajoules  Terajoules
# 1         Country                       BALANCE         NaN         NaN
# 2       Argentina   Receipts from Other Sources           -           -
# 3       Argentina                       Imports        4633        6116
# 4       Argentina                           LNG        4818        6361
# ..            ...                           ...         ...         ...
# 72  United States   Receipts from Other Sources           -           -
# 73  United States                       Imports           -           -
# 74  United States                           LNG           -           -
# 75  United States                      Pipeline           -           -
# 76  United States                           LNG           -           -
#
#        Mar2009     Apr2009     May2009     Jun2009     Jul2009     Aug2009  \
# 0   Terajoules  Terajoules  Terajoules  Terajoules  Terajoules  Terajoules
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2            -           -           -           -           -           -
# 3         5649        5695        5188        5380        6337        5952
# 4         5875        5924        5396        5596        6591        6191
# ..         ...         ...         ...         ...         ...         ...
# 72           -           -           -           -           -           -
# 73           -           -           -           -           -           -
# 74           -           -           -           -           -           -
# 75           -           -           -           -           -           -
# 76           -           -           -           -           -           -
#
#     ...     Jun2024     Jul2024     Aug2024     Sep2024     Oct2024  \
# 0   ...  Terajoules  Terajoules  Terajoules  Terajoules  Terajoules
# 1   ...         NaN         NaN         NaN         NaN         NaN
# 2   ...           -           -           -           -           -
# 3   ...           -           -           -           -           -
# 4   ...           -           -           -           -           -
# ..  ...         ...         ...         ...         ...         ...
# 72  ...           0           0           0           0           0
# 73  ...      275411      302960      291138      275223      283452
# 74  ...          39          39          79        2413          79
# 75  ...      275372      302921      291059      272810      283373
# 76  ...      397040      359190      404945      404546      418904
#
#        Nov2024     Dec2024     Jan2025     Feb2025     Mar2025
# 0   Terajoules  Terajoules  Terajoules  Terajoules  Terajoules
# 1          NaN         NaN         NaN         NaN         NaN
# 2            -           -           -           -           -
# 3            -           -           -           -           -
# 4            -           -           -           -           -
# ..         ...         ...         ...         ...         ...
# 72           0           0           0           0           -
# 73      301817      345325      373979      339602           -
# 74          39        2480        2008           0           -
# 75      301778      342845      371971      339602           -
# 76      418868      457769      462405      489988           -
#
# [77 rows x 197 columns]
