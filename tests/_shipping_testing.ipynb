# %%
from h2_gym.envs.shipping import ShippingEnv
import h2_gym
from pathlib import Path
from pandas import read_csv

# %%
path = Path(h2_gym.__file__).parent / "data/shipping/demand/src/data/analyzed/monthly_demand_clean.csv"
data = read_csv(path)
data = data[(data['country'] == 'EU') & (data['type'] == 'industry')]
data.plot(y='demand',title='EU Industry Demand', figsize=(20, 10),ylim=[0,120])
# Out:
# /Users/cameronaldren/Documents/h2-gym/src/h2_gym/data/shipping/demand/src/data/analyzed/monthly_demand_clean.csv
# <Axes: title={'center': 'EU Industry Demand'}>

# %%
path = Path(h2_gym.__file__).parent / "data/shipping/demand/src/data/analyzed/daily_demand_clean.csv"
data = read_csv(path)
data = data[(data['country'] == 'FR') & (data['type'] == 'industry')]
data.plot(y='demand',title='EU Industry Demand', figsize=(20, 10),ylim=[0,5.5e8])
# Out:
# <Axes: title={'center': 'EU Industry Demand'}>
