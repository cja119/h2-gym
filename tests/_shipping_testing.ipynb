# %%
from h2_gym.data.shipping import NGDemand

# %%
data = NGDemand('jodi-gas_wdb_16147546018076.csv')

# %%
data._data.rename(columns={data._data.columns[0]: "Country"}, inplace=True)
data._data.set_index("Country", inplace=True)

# %%
data._data.loc['United Kingdom']
# Out:
#                                         TIME Jan2009 Feb2009 Mar2009 Apr2009  \
# Country
# United Kingdom   Receipts from Other Sources       -       -       -       -
# United Kingdom                       Imports       -       -       -       -
# United Kingdom                           LNG       -       -       -       -
# United Kingdom                      Pipeline       -       -       -       -
# United Kingdom                           LNG       -       -       -       -
#
#                May2009 Jun2009 Jul2009 Aug2009 Sep2009  ... Jun2024 Jul2024  \
# Country                                                 ...
# United Kingdom       -       -       -       -       -  ...    1969    2122
# United Kingdom       -       -       -       -       -  ...   96669  119049
# United Kingdom       -       -       -       -       -  ...    9778    3374
# United Kingdom       -       -       -       -       -  ...   86891  115675
# ...
